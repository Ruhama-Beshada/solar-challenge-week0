# %% [markdown]
# # Benin EDA — Solar Dataset
#
# **Objective:** Profile, clean, and explore the Benin solar dataset end-to-end according to Task 2.
#
# **Details:**
# - Author: Ruhama B.
# - Branch: `eda-benin`
# - Data: `data/benin.csv` -> cleaned export `data/benin_clean.csv` (do **not** commit CSVs)
