# %% [markdown]
# # Togo EDA — Solar Dataset
#
# **Objective:** Profile, clean, and explore the Benin solar dataset end-to-end according to Task 2.
#
# **Details:**
# - Author: Ruhama B.
# - Branch: `eda-togo`
# - Data: `data/togo-dapaong_qc.csv` -> cleaned export `data/togo-dapaong_qc_clean.csv` (do **not** commit CSVs)
